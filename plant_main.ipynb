# %%
from flask import Flask, render_template, request, redirect, send_from_directory, url_for
import numpy as np
import json
import uuid
import os
import tensorflow as tf

# Create Flask app
app = Flask(__name__)

# Load model
model = tf.keras.models.load_model(
    r"C:\Users\gargi\Desktop\Kartikay\plant\model\plant_cnn.keras"
)

# Class labels
label = ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy',
         'Background_without_leaves', 'Blueberry___healthy', 'Cherry___Powdery_mildew', 'Cherry___healthy',
         'Corn___Cercospora_leaf_spot Gray_leaf_spot', 'Corn___Common_rust', 'Corn___Northern_Leaf_Blight',
         'Corn___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
         'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy',
         'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight',
         'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew',
         'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight',
         'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot',
         'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
         'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']

# Load disease descriptions
with open("plant_disease.json", 'r') as file:
    plant_disease = json.load(file)

# Route to serve uploaded images
@app.route('/uploadimages/<path:filename>')
def uploaded_images(filename):
    return send_from_directory('./uploadimages', filename)

# Home page
@app.route('/', methods=['GET'])
def home():
    return render_template('home.html')

# Preprocessing function
def extract_features(image):
    image = tf.keras.utils.load_img(image, target_size=(160, 160))
    feature = tf.keras.utils.img_to_array(image)
    feature = np.array([feature])
    return feature

# Prediction function
def model_predict(image):
    img = extract_features(image)
    prediction = model.predict(img)
    prediction_label = plant_disease[prediction.argmax()]
    return prediction_label

# Upload image and predict
@app.route('/upload/', methods=['POST', 'GET'])
def uploadimage():
    if request.method == "POST":
        image = request.files['img']
        
        # Ensure upload folder exists
        upload_folder = "uploadimages"
        if not os.path.exists(upload_folder):
            os.makedirs(upload_folder)

        filename = f"temp_{uuid.uuid4().hex}_{image.filename}"
        save_path = os.path.join(upload_folder, filename)
        image.save(save_path)

        prediction = model_predict(save_path)
        return render_template('home.html', result=True,
                               imagepath=f'/uploadimages/{filename}',
                               prediction=prediction)
    else:
        return redirect('/')

# Start Flask app in notebook cell
app.run(port=5000, debug=False, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# C:\Users\gargi\AppData\Roaming\Python\Python311\site-packages\keras\src\saving\saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 58 variables whereas the saved optimizer has 114 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Jun/2025 11:49:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 11:49:09] "GET /static/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 11:49:09] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 11:49:09] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 11:49:09] "GET /static/images/logo.svg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 11:49:09] "GET /static/images/crop_background1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 11:49:09] "GET /static/images/crop_background2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:28:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 12:28:54] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:28:54] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:28:55] "GET /static/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:28:55] "GET /static/images/logo.svg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:28:55] "GET /static/images/crop_background1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:28:55] "GET /static/images/crop_background2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:29:00] "GET /static/images/crop_background3.jpg HTTP/1.1" 304 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 127.0.0.1 - - [06/Jun/2025 12:29:04] "POST /upload/ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 12:29:04] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:29:04] "GET /uploadimages/temp_9d581ae9b7f74901837b9c9603e269b8_image%20(2).JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 12:29:04] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:29:04] "GET /static/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:29:04] "GET /static/images/logo.svg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:30:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 12:30:31] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:30:31] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:30:31] "GET /static/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:30:31] "GET /static/images/logo.svg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:30:31] "GET /static/images/crop_background1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:30:31] "GET /static/images/crop_background2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:30:36] "GET /static/images/crop_background3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:30:41] "GET /static/images/crop_background4.jpg HTTP/1.1" 304 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 127.0.0.1 - - [06/Jun/2025 12:31:48] "POST /upload/ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 12:31:48] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:31:48] "GET /uploadimages/temp_dea92422aef34c4e916146d1d5c1fae5_image%20(3).JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 12:31:48] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:31:48] "GET /static/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:31:48] "GET /static/images/logo.svg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:31:48] "GET /static/images/crop_background1.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:31:48] "GET /static/images/crop_background2.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:31:53] "GET /static/images/crop_background3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:31:58] "GET /static/images/crop_background4.jpg HTTP/1.1" 304 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 127.0.0.1 - - [06/Jun/2025 12:32:18] "POST /upload/ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 12:32:18] "GET /uploadimages/temp_828002ffada44c4486acc186662d2433_temp_d103f650a18c449cab49c9525c1ed147_temp_f3f0be96b3f94ef79bed90f5ed6ff2a0_image%20(1)%20(1).jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2025 12:32:18] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:32:18] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:32:18] "GET /static/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Jun/2025 12:32:18] "GET /static/images/logo.svg HTTP/1.1" 304 -
